# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 2 - Phase 3 - Elaine

# %% [markdown]
# This phase aims at:
#
# - Compiling the target corpus for a pilot Lexical Multi-Dimensional Analysis.

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# Make sure the prerequisites in [CL_LMDA_prerequisites](https://github.com/laelgelc/laelgelc/blob/main/CL_LMDA_prerequisites.ipynb) are satisfied.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas
# - numpy
# - seaborn
# - matplotlib

# %% [markdown]
# ## Import the required libraries

# %%
import os
import sys
import pandas as pd
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Define input variables

# %%
input_directory = 'cl_st2_ph3_elaine'
output_directory = 'cl_st2_ph3_elaine'
dataset_filename_2 = 'cl_st2_ph3_elaine_dataset'
dataset_filename_3 = 'cl_st2_ph3_elaine_tc'
dataset_filename_4 = 'cl_st2_ph3_elaine_tc_2'

# %% [markdown]
# ## Create output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory already exists.

# %% [markdown]
# ## Import the data into a DataFrame

# %%
df_ted = pd.read_json(f'{input_directory}/{dataset_filename_2}.jsonl', lines=True)

# %%
df_ted
# Out:
#                   Root Directory                        File  \
# 0     CoTED2_TED_TEDEX_1984_2025       T0004_AM_TED_2019.txt
# 1     CoTED2_TED_TEDEX_1984_2025       T0006_AV_TED_2019.txt
# 2     CoTED2_TED_TEDEX_1984_2025      T0007_AAB_TED_2019.txt
# 3     CoTED2_TED_TEDEX_1984_2025       T0008_BV_TED_2019.txt
# 4     CoTED2_TED_TEDEX_1984_2025   T0009_BW_TED_RES_2019.txt
# ...                          ...                         ...
# 4310  CoTED2_TED_TEDEX_1984_2025  T5897_CH_TED_TWWW_2020.txt
# 4311  CoTED2_TED_TEDEX_1984_2025  T5898_EO_TED_TWWW_2020.txt
# 4312  CoTED2_TED_TEDEX_1984_2025  T5899_TD_TED_TWWW_2020.txt
# 4313  CoTED2_TED_TEDEX_1984_2025  T5900_LR_TED_TWWW_2020.txt
# 4314  CoTED2_TED_TEDEX_1984_2025  T5901_LF_TED_TWWW_2020.txt
#
#                                               File Path  Text ID  Year  \
# 0      CoTED2_TED_TEDEX_1984_2025/T0004_AM_TED_2019.txt  t000000  2019
# 1      CoTED2_TED_TEDEX_1984_2025/T0006_AV_TED_2019.txt  t000001  2019
# 2     CoTED2_TED_TEDEX_1984_2025/T0007_AAB_TED_2019.txt  t000002  2019
# 3      CoTED2_TED_TEDEX_1984_2025/T0008_BV_TED_2019.txt  t000003  2019
# 4     CoTED2_TED_TEDEX_1984_2025/T0009_BW_TED_RES_20...  t000004  2019
# ...                                                 ...      ...   ...
# 4310  CoTED2_TED_TEDEX_1984_2025/T5897_CH_TED_TWWW_2...  t004312  2020
# 4311  CoTED2_TED_TEDEX_1984_2025/T5898_EO_TED_TWWW_2...  t004313  2020
# 4312  CoTED2_TED_TEDEX_1984_2025/T5899_TD_TED_TWWW_2...  t004314  2020
# 4313  CoTED2_TED_TEDEX_1984_2025/T5900_LR_TED_TWWW_2...  t004315  2020
# 4314  CoTED2_TED_TEDEX_1984_2025/T5901_LF_TED_TWWW_2...  t004316  2020
#
#       Word Count NLTK                                               Text
# 0                2507  I spent the past three years talking to some o...
# 1                1115  [This is an improvised talk (and intro) based ...
# 2                1734  So one of the most important solutions to the ...
# 3                1736  So in the winter of 2012, I went to visit my g...
# 4                1223  For all that's ever been said about climate ch...
# ...               ...                                                ...
# 4310              963  I was not one of those kids that knew exactly ...
# 4311             1071  When I was pregnant, I just got very frustrate...
# 4312              752  When you think about money and your dreams and...
# 4313              920  If you look at a carpenter, they have a toolbo...
# 4314              813  No matter how hard you might try, you can't ju...
#
# [4315 rows x 7 columns]

# %%
df_ted.dtypes
# Out:
# Root Directory     object
# File               object
# File Path          object
# Text ID            object
# Year                int64
# Word Count NLTK     int64
# Text               object
# dtype: object

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# ### Drop short paragraphs

# %% [markdown]
# #### Shorter than 10 words

# %%
mask_short = df_ted['Word Count NLTK'] <= 10
df_short_paragraphs = df_ted.loc[mask_short, ['Text']]
df_short_paragraphs
# Out:
# Empty DataFrame
# Columns: [Text]
# Index: []

# %% [markdown]
# #### Drop the paragraphs

# %%
# Drop rows from df_ted where mask_short is True
initial_count = len(df_ted)
removed_count = int(mask_short.sum())

df_ted = df_ted.loc[~mask_short].reset_index(drop=True)

print(f"Dropped {removed_count} short paragraphs; remaining rows: {len(df_ted)}")
df_ted
# Out:
# Dropped 0 short paragraphs; remaining rows: 4315
#                   Root Directory                        File  \
# 0     CoTED2_TED_TEDEX_1984_2025       T0004_AM_TED_2019.txt
# 1     CoTED2_TED_TEDEX_1984_2025       T0006_AV_TED_2019.txt
# 2     CoTED2_TED_TEDEX_1984_2025      T0007_AAB_TED_2019.txt
# 3     CoTED2_TED_TEDEX_1984_2025       T0008_BV_TED_2019.txt
# 4     CoTED2_TED_TEDEX_1984_2025   T0009_BW_TED_RES_2019.txt
# ...                          ...                         ...
# 4310  CoTED2_TED_TEDEX_1984_2025  T5897_CH_TED_TWWW_2020.txt
# 4311  CoTED2_TED_TEDEX_1984_2025  T5898_EO_TED_TWWW_2020.txt
# 4312  CoTED2_TED_TEDEX_1984_2025  T5899_TD_TED_TWWW_2020.txt
# 4313  CoTED2_TED_TEDEX_1984_2025  T5900_LR_TED_TWWW_2020.txt
# 4314  CoTED2_TED_TEDEX_1984_2025  T5901_LF_TED_TWWW_2020.txt
#
#                                               File Path  Text ID  Year  \
# 0      CoTED2_TED_TEDEX_1984_2025/T0004_AM_TED_2019.txt  t000000  2019
# 1      CoTED2_TED_TEDEX_1984_2025/T0006_AV_TED_2019.txt  t000001  2019
# 2     CoTED2_TED_TEDEX_1984_2025/T0007_AAB_TED_2019.txt  t000002  2019
# 3      CoTED2_TED_TEDEX_1984_2025/T0008_BV_TED_2019.txt  t000003  2019
# 4     CoTED2_TED_TEDEX_1984_2025/T0009_BW_TED_RES_20...  t000004  2019
# ...                                                 ...      ...   ...
# 4310  CoTED2_TED_TEDEX_1984_2025/T5897_CH_TED_TWWW_2...  t004312  2020
# 4311  CoTED2_TED_TEDEX_1984_2025/T5898_EO_TED_TWWW_2...  t004313  2020
# 4312  CoTED2_TED_TEDEX_1984_2025/T5899_TD_TED_TWWW_2...  t004314  2020
# 4313  CoTED2_TED_TEDEX_1984_2025/T5900_LR_TED_TWWW_2...  t004315  2020
# 4314  CoTED2_TED_TEDEX_1984_2025/T5901_LF_TED_TWWW_2...  t004316  2020
#
#       Word Count NLTK                                               Text
# 0                2507  I spent the past three years talking to some o...
# 1                1115  [This is an improvised talk (and intro) based ...
# 2                1734  So one of the most important solutions to the ...
# 3                1736  So in the winter of 2012, I went to visit my g...
# 4                1223  For all that's ever been said about climate ch...
# ...               ...                                                ...
# 4310              963  I was not one of those kids that knew exactly ...
# 4311             1071  When I was pregnant, I just got very frustrate...
# 4312              752  When you think about money and your dreams and...
# 4313              920  If you look at a carpenter, they have a toolbo...
# 4314              813  No matter how hard you might try, you can't ju...
#
# [4315 rows x 7 columns]

# %% [markdown]
# ### Drop duplicate paragraphs

# %% [markdown]
# #### Identify duplicate paragraphs

# %%
mask_dupes = df_ted['Text'].notna() & df_ted['Text'].duplicated(keep=False)
df_ted.loc[mask_dupes, ['Text']].sort_values('Text')
# Out:
# Empty DataFrame
# Columns: [Text]
# Index: []

# %% [markdown]
# #### Drop the paragraphs

# %%
# Drop duplicate paragraphs, keeping the first occurrence
mask_drop_dupes = df_ted['Text'].duplicated(keep='first')
removed_dupes = int(mask_drop_dupes.sum())

df_ted = df_ted.loc[~mask_drop_dupes].reset_index(drop=True)

print(f"Dropped {removed_dupes} duplicate paragraphs; remaining rows: {len(df_ted)}")
df_ted
# Out:
# Dropped 0 duplicate paragraphs; remaining rows: 4315
#                   Root Directory                        File  \
# 0     CoTED2_TED_TEDEX_1984_2025       T0004_AM_TED_2019.txt
# 1     CoTED2_TED_TEDEX_1984_2025       T0006_AV_TED_2019.txt
# 2     CoTED2_TED_TEDEX_1984_2025      T0007_AAB_TED_2019.txt
# 3     CoTED2_TED_TEDEX_1984_2025       T0008_BV_TED_2019.txt
# 4     CoTED2_TED_TEDEX_1984_2025   T0009_BW_TED_RES_2019.txt
# ...                          ...                         ...
# 4310  CoTED2_TED_TEDEX_1984_2025  T5897_CH_TED_TWWW_2020.txt
# 4311  CoTED2_TED_TEDEX_1984_2025  T5898_EO_TED_TWWW_2020.txt
# 4312  CoTED2_TED_TEDEX_1984_2025  T5899_TD_TED_TWWW_2020.txt
# 4313  CoTED2_TED_TEDEX_1984_2025  T5900_LR_TED_TWWW_2020.txt
# 4314  CoTED2_TED_TEDEX_1984_2025  T5901_LF_TED_TWWW_2020.txt
#
#                                               File Path  Text ID  Year  \
# 0      CoTED2_TED_TEDEX_1984_2025/T0004_AM_TED_2019.txt  t000000  2019
# 1      CoTED2_TED_TEDEX_1984_2025/T0006_AV_TED_2019.txt  t000001  2019
# 2     CoTED2_TED_TEDEX_1984_2025/T0007_AAB_TED_2019.txt  t000002  2019
# 3      CoTED2_TED_TEDEX_1984_2025/T0008_BV_TED_2019.txt  t000003  2019
# 4     CoTED2_TED_TEDEX_1984_2025/T0009_BW_TED_RES_20...  t000004  2019
# ...                                                 ...      ...   ...
# 4310  CoTED2_TED_TEDEX_1984_2025/T5897_CH_TED_TWWW_2...  t004312  2020
# 4311  CoTED2_TED_TEDEX_1984_2025/T5898_EO_TED_TWWW_2...  t004313  2020
# 4312  CoTED2_TED_TEDEX_1984_2025/T5899_TD_TED_TWWW_2...  t004314  2020
# 4313  CoTED2_TED_TEDEX_1984_2025/T5900_LR_TED_TWWW_2...  t004315  2020
# 4314  CoTED2_TED_TEDEX_1984_2025/T5901_LF_TED_TWWW_2...  t004316  2020
#
#       Word Count NLTK                                               Text
# 0                2507  I spent the past three years talking to some o...
# 1                1115  [This is an improvised talk (and intro) based ...
# 2                1734  So one of the most important solutions to the ...
# 3                1736  So in the winter of 2012, I went to visit my g...
# 4                1223  For all that's ever been said about climate ch...
# ...               ...                                                ...
# 4310              963  I was not one of those kids that knew exactly ...
# 4311             1071  When I was pregnant, I just got very frustrate...
# 4312              752  When you think about money and your dreams and...
# 4313              920  If you look at a carpenter, they have a toolbo...
# 4314              813  No matter how hard you might try, you can't ju...
#
# [4315 rows x 7 columns]

# %% [markdown]
# ### Determine the `Paragraph Count` per `Document Type`

# %%
df_texts_per_year = (
    df_ted
    .groupby('Year', dropna=False)
    .size()
    .reset_index(name='Text Count')
    .sort_values(['Year'], ascending=[True])
    .reset_index(drop=True)
)
df_texts_per_year
# Out:
#     Year  Text Count
# 0   1984           1
# 1   1990           1
# 2   1994           1
# 3   1998           6
# 4   2001           4
# 5   2002          25
# 6   2003          31
# 7   2004          30
# 8   2005          61
# 9   2006          41
# 10  2007         101
# 11  2008          74
# 12  2009         200
# 13  2010         219
# 14  2011         235
# 15  2012         253
# 16  2013         266
# 17  2014         237
# 18  2015         237
# 19  2016         271
# 20  2017         342
# 21  2018         261
# 22  2019         104
# 23  2020         281
# 24  2021         294
# 25  2022         246
# 26  2023         284
# 27  2024         205
# 28  2025           4

# %% [markdown]
# ### Export to a file

# %%
df_ted.to_json(f"{output_directory}/{dataset_filename_3}.jsonl", orient='records', lines=True)

# %%
df_ted.to_excel(f"{output_directory}/{dataset_filename_3}.xlsx", index=False)

# %% [markdown]
# ## Import the Target Corpus into a DataFrame

# %%
df_ted_tc = pd.read_json(f"{output_directory}/{dataset_filename_3}.jsonl", lines=True)

# %%
df_ted_tc
# Out:
#                   Root Directory                        File  \
# 0     CoTED2_TED_TEDEX_1984_2025       T0004_AM_TED_2019.txt
# 1     CoTED2_TED_TEDEX_1984_2025       T0006_AV_TED_2019.txt
# 2     CoTED2_TED_TEDEX_1984_2025      T0007_AAB_TED_2019.txt
# 3     CoTED2_TED_TEDEX_1984_2025       T0008_BV_TED_2019.txt
# 4     CoTED2_TED_TEDEX_1984_2025   T0009_BW_TED_RES_2019.txt
# ...                          ...                         ...
# 4310  CoTED2_TED_TEDEX_1984_2025  T5897_CH_TED_TWWW_2020.txt
# 4311  CoTED2_TED_TEDEX_1984_2025  T5898_EO_TED_TWWW_2020.txt
# 4312  CoTED2_TED_TEDEX_1984_2025  T5899_TD_TED_TWWW_2020.txt
# 4313  CoTED2_TED_TEDEX_1984_2025  T5900_LR_TED_TWWW_2020.txt
# 4314  CoTED2_TED_TEDEX_1984_2025  T5901_LF_TED_TWWW_2020.txt
#
#                                               File Path  Text ID  Year  \
# 0      CoTED2_TED_TEDEX_1984_2025/T0004_AM_TED_2019.txt  t000000  2019
# 1      CoTED2_TED_TEDEX_1984_2025/T0006_AV_TED_2019.txt  t000001  2019
# 2     CoTED2_TED_TEDEX_1984_2025/T0007_AAB_TED_2019.txt  t000002  2019
# 3      CoTED2_TED_TEDEX_1984_2025/T0008_BV_TED_2019.txt  t000003  2019
# 4     CoTED2_TED_TEDEX_1984_2025/T0009_BW_TED_RES_20...  t000004  2019
# ...                                                 ...      ...   ...
# 4310  CoTED2_TED_TEDEX_1984_2025/T5897_CH_TED_TWWW_2...  t004312  2020
# 4311  CoTED2_TED_TEDEX_1984_2025/T5898_EO_TED_TWWW_2...  t004313  2020
# 4312  CoTED2_TED_TEDEX_1984_2025/T5899_TD_TED_TWWW_2...  t004314  2020
# 4313  CoTED2_TED_TEDEX_1984_2025/T5900_LR_TED_TWWW_2...  t004315  2020
# 4314  CoTED2_TED_TEDEX_1984_2025/T5901_LF_TED_TWWW_2...  t004316  2020
#
#       Word Count NLTK                                               Text
# 0                2507  I spent the past three years talking to some o...
# 1                1115  [This is an improvised talk (and intro) based ...
# 2                1734  So one of the most important solutions to the ...
# 3                1736  So in the winter of 2012, I went to visit my g...
# 4                1223  For all that's ever been said about climate ch...
# ...               ...                                                ...
# 4310              963  I was not one of those kids that knew exactly ...
# 4311             1071  When I was pregnant, I just got very frustrate...
# 4312              752  When you think about money and your dreams and...
# 4313              920  If you look at a carpenter, they have a toolbo...
# 4314              813  No matter how hard you might try, you can't ju...
#
# [4315 rows x 7 columns]

# %% [markdown]
# ### Identify occurrences of the `pipe` character in the `Text Paragraph` column

# %% [markdown]
# Further on, a few columns of the DataFrame are going to be exported into the file `tweets.txt` whose columns need to be delimited by the `pipe` character. Therefore, it is recommended that any occurrences of the `pipe` character in the `Text Paragraph` column are replaced by another character.

# %%
mask_pipe = df_ted_tc['Text'].str.contains(r'\|', na=False)
df_with_pipe = df_ted_tc.loc[mask_pipe, ['Text']]
df_with_pipe
# Out:
#                                                    Text
# 3319  The ways of the world often baffle me. I somet...

# %%
# Defining a function to replace the 'pipe' character by the '-' character
def replace_pipe_with_hyphen(input_string):
    modified_string = re.sub(r'\|', '-', input_string)
    return modified_string

# Replacing the 'pipe' character by the '-' character
df_ted_tc['Text'] = df_ted_tc['Text'].apply(replace_pipe_with_hyphen)

# %% [markdown]
# ## Identify nonverbal event markers

# %%
# Task: From df_ted_tc, extract all substrings enclosed in parentheses in the Text column,
# and create a set of unique phrases (including the parentheses).

# Ensure required imports are available (re already imported earlier in the notebook)
#import re

# Ensure df_ted_tc exists with a 'Text' column
if 'df_ted_tc' in globals() and isinstance(df_ted_tc, pd.DataFrame) and 'Text' in df_ted_tc.columns:
    # Regex to capture non-greedy content between parentheses, handling multiple per row
    pattern = re.compile(r'\([^()]*\)')
    # Extract lists of matches per row (skip NaN safely), then flatten
    all_paren_phrases = (
        df_ted_tc['Text']
        .dropna()
        .astype(str)
        .apply(pattern.findall)
        .explode()
        .dropna()
        .tolist()
    )
    phrases_in_parentheses = set(all_paren_phrases)

    print(f"Unique parenthetical phrases found: {len(phrases_in_parentheses)}")
else:
    phrases_in_parentheses = set()
    print("df_ted_tc with column 'Text' is not available.")

# Optionally preview a few items deterministically
#preview = sorted(list(phrases_in_parentheses))[:20]
#preview
# Out:
# Unique parenthetical phrases found: 1321

# %%
# Task: From the existing `phrases_in_parentheses` set, build a DataFrame with counts
# and export it as JSON.

# Ensure required imports are available (pandas and os already imported earlier in the notebook)
#import pandas as pd
#import os

# Validate source set
if 'phrases_in_parentheses' in globals() and isinstance(phrases_in_parentheses, set):
    # We also need counts per phrase from the original list of occurrences
    if 'all_paren_phrases' in globals() and isinstance(all_paren_phrases, list):
        # Build counts using pandas
        s = pd.Series(all_paren_phrases, dtype="string").dropna()
        df_phrases_in_parentheses = (
            s.value_counts()
            .rename_axis('Phrases in Parentheses')
            .reset_index(name='Count')
        )
    else:
        # Fall back: create counts = 1 for each unique phrase if the full list isn't available
        df_phrases_in_parentheses = pd.DataFrame(
            {'Phrases in Parentheses': sorted(list(phrases_in_parentheses)),
             'Count': 1}
        )
else:
    # Empty fallback
    df_phrases_in_parentheses = pd.DataFrame(
        {'Phrases in Parentheses': pd.Series(dtype="string"),
         'Count': pd.Series(dtype="int")}
    )

# Preview
#df_phrases_in_parentheses

# Export to JSON (records)
export_json_path = os.path.join(output_directory if 'output_directory' in globals() else '.',
                                'phrases_in_parentheses_counts.json')
df_phrases_in_parentheses.to_json(export_json_path, orient='records', force_ascii=False)
print(f"Exported df_phrases_in_parentheses to {export_json_path} with {len(df_phrases_in_parentheses)} rows.")
# Out:
# Exported df_phrases_in_parentheses to cl_st2_ph3_elaine/phrases_in_parentheses_counts.json with 1321 rows.

# %% [markdown]
# After examining the frequency of nonlexical event annotations, we decided to exclude them from the analysis as they may distort the Lexical Multi-Dimensional Analysis.
#
# ```
#   {
#     "Phrases in Parentheses": "(Laughter)",
#     "Count": 15108
#   },
#   {
#     "Phrases in Parentheses": "(Applause)",
#     "Count": 8059
#   },
# ```

# %%
# Task: Remove all occurrences of phrases from df_phrases_in_parentheses['Phrases in Parentheses']
# from df_ted_tc['Text'].

# Preconditions check
required_dfs_ok = (
        'df_ted_tc' in globals() and isinstance(df_ted_tc, pd.DataFrame) and 'Text' in df_ted_tc.columns and
        'df_phrases_in_parentheses' in globals() and isinstance(df_phrases_in_parentheses, pd.DataFrame) and
        'Phrases in Parentheses' in df_phrases_in_parentheses.columns
)

if required_dfs_ok:
    # Build an efficient single regex pattern that matches any of the phrases literally
    phrases = (
        df_phrases_in_parentheses['Phrases in Parentheses']
        .dropna()
        .astype(str)
        .unique()
        .tolist()
    )
    if phrases:
        # Escape each phrase to avoid regex meta-character issues
        escaped = [re.escape(p) for p in phrases]
        # Join with alternation; use non-capturing group for safety
        pattern_parentheses_phrases = re.compile(r'(?:' + '|'.join(escaped) + r')')

        # Replace all occurrences with empty string; preserve NaNs
        df_ted_tc['Text'] = df_ted_tc['Text'].astype(str).str.replace(pattern_parentheses_phrases, '', regex=True)

        # Optional: collapse extra spaces introduced by removals and trim
        df_ted_tc['Text'] = df_ted_tc['Text'].str.replace(r'\s+', ' ', regex=True).str.strip()
    else:
        print("No phrases provided to remove.")
else:
    print(
        "Required DataFrames or columns are missing: df_ted_tc['Text'] and df_phrases_in_parentheses['Phrases in Parentheses'].")

# %% [markdown]
# ## Tokenise

# %% [markdown]
# Please refer to [What is tokenization in NLP?](https://www.analyticsvidhya.com/blog/2020/05/what-is-tokenization-nlp/).

# %% [markdown]
# ### Inspect one row

# %%
print(df_ted_tc.at[3319, 'Text'])
# Out:
# The ways of the world often baffle me. I sometimes wonder if I missed the memo about the most basic things. What are you supposed to make for dinner? What do you talk about in an elevator? Why do people cut in line? How do you leave a dinner party without being rude? Or do you leave it all? ["Why are you still here?"] My tendency to see the world like I'm from outer space was a bit of a liability when I was a kid. True story. ["What's a noogie?"] But it's been helpful in my career. I'm a cartoonist. When I first started making cartoons for The New Yorker about a decade ago, I kept my ideas light and quirky. And please shout out if you don't get any of them, I'll explain. ["The synchronized swim team quits"] I didn't draw anything too personal. ["Unicorns do exist!"] I mean, personal for someone. I figured I was too specific, too hard to relate to and read, possibly, too female. It took a breakup. ["I know there would be a time I could wear them without destroying my feet."] It took a breakup to get me to start drawing more autobiographically. The pain I was feeling, although objectively pretty run of the mill, was impossible to ignore. [Tunnel of love] I knew that drying was my strongest problem-solving tool. So I decided to diagram what I was going through. [Tunnel of love. Just kidding. Wall of death.] By making these drawings, I could see how my ex and I had hurt each other. And move on. Onto other breakups. ["Again?" Pit of despair] Drawing from my own life was a revelation to me, not only because it helped me understand myself better, but because it made me see for the first time that people could relate to me. Now that I had this amazing tool, there were so many problems I wanted to solve with it. The problem of scheduling. [Work - Family / Friends] The problem of too many things happening all at the same time. [ "I'm having a birthday party! "I'm visiting New York!"] The problem, relatedly, of time. [Childhood / now] And finally, dating again. There's an endless amount to say about dating. There are, of course, problems that can't be summed up in a single drawing. For these problems, you need many drawings. One more complex problem I have is with God. I'm Jewish, so I'm talking about the God of the Old Testament. My problem with God isn't actually a big problem. It's just, I don't know, it's stayed with me. My problem with God is that he's too confident. For me, creation is an act of solving problems, of figuring things out. God already seems to have everything figured out. He strikes me as more of a king than a creator. And I'm not sure you can be both. As an experiment, I decided to remake the Book of Genesis as a graphic novel. My version of God is not confident. And maybe not coincidentally, she's a woman. It surprised me how few changes I needed to make to the original text, which is sparse and ancient and lends itself well to interpretation. For example, the Bible opens in this mysterious, moody way with God floating aimlessly on the face of a dark, mysterious void. In my version, I have her floating this way because she's feeling despondent about her limitations as an artist. She's made this messy, wet, mixed up dark first drafts of the world, and she just doesn't know where to go from here. My version of God doesn't know exactly what she's doing, but she draws a horizon line, and things start to fall into place. She banishes Adam and Eve from the Garden of Eden, not because they disobeyed her, but because, by eating the apple and becoming wise, she feels they have outgrown the world she created for them, and she needs to let them go. She scatters the builders of the Tower of Babel, not because she's threatened by their power, but because, like any introvert, she needs her privacy. When she destroys the world in the story of Noah, it's not because she's incensed with mankind, but because she's incensed with herself. She knows she could have done a better job when she made us. My adaptation of the Book of Genesis  ...

# %% [markdown]
# ### Tokenise

# %%
# Defining a function to tokenise a string
def tokenise_string(input_line):
    # Replace URLs with placeholders
    url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+\b'
    placeholder = '<URL>'  # Choose a unique placeholder
    urls = re.findall(url_pattern, input_line)
    tokenised_line = re.sub(url_pattern, placeholder, input_line)  # Replace URLs with placeholders

    # Replace curly quotes with straight ones
    tokenised_line = tokenised_line.replace('“', '"').replace('”', '"').replace("‘", "'").replace("’", "'")
    # Separate common punctuation marks with spaces
    tokenised_line = re.sub(r'([.\!?,"\'/()])', r' \1 ', tokenised_line)
    # Add a space before '#'
    tokenised_line = re.sub(r'(?<!\s)#', r' #', tokenised_line)  # Add a space before '#' if it is not already preceded by one
    # Reduce extra spaces by a single space
    tokenised_line = re.sub(r'\s+', ' ', tokenised_line)

    # Replace the placeholders with the respective URLs
    for url in urls:
        tokenised_line = tokenised_line.replace(placeholder, url, 1)

    return tokenised_line

# Tokenising the strings
df_ted_tc['Text'] = df_ted_tc['Text'].apply(tokenise_string)

# %% [markdown]
# ### Reinspect the row

# %%
print(df_ted_tc.at[3319, 'Text'])
# Out:
# The ways of the world often baffle me . I sometimes wonder if I missed the memo about the most basic things . What are you supposed to make for dinner ? What do you talk about in an elevator ? Why do people cut in line ? How do you leave a dinner party without being rude ? Or do you leave it all ? [ " Why are you still here ? " ] My tendency to see the world like I ' m from outer space was a bit of a liability when I was a kid . True story . [ " What ' s a noogie ? " ] But it ' s been helpful in my career . I ' m a cartoonist . When I first started making cartoons for The New Yorker about a decade ago , I kept my ideas light and quirky . And please shout out if you don ' t get any of them , I ' ll explain . [ " The synchronized swim team quits " ] I didn ' t draw anything too personal . [ " Unicorns do exist ! " ] I mean , personal for someone . I figured I was too specific , too hard to relate to and read , possibly , too female . It took a breakup . [ " I know there would be a time I could wear them without destroying my feet . " ] It took a breakup to get me to start drawing more autobiographically . The pain I was feeling , although objectively pretty run of the mill , was impossible to ignore . [Tunnel of love] I knew that drying was my strongest problem-solving tool . So I decided to diagram what I was going through . [Tunnel of love . Just kidding . Wall of death . ] By making these drawings , I could see how my ex and I had hurt each other . And move on . Onto other breakups . [ " Again ? " Pit of despair] Drawing from my own life was a revelation to me , not only because it helped me understand myself better , but because it made me see for the first time that people could relate to me . Now that I had this amazing tool , there were so many problems I wanted to solve with it . The problem of scheduling . [Work - Family / Friends] The problem of too many things happening all at the same time . [ " I ' m having a birthday party ! " I ' m visiting New York ! " ] The problem , relatedly , of time . [Childhood / now] And finally , dating again . There ' s an endless amount to say about dating . There are , of course , problems that can ' t be summed up in a single drawing . For these problems , you need many drawings . One more complex problem I have is with God . I ' m Jewish , so I ' m talking about the God of the Old Testament . My problem with God isn ' t actually a big problem . It ' s just , I don ' t know , it ' s stayed with me . My problem with God is that he ' s too confident . For me , creation is an act of solving problems , of figuring things out . God already seems to have everything figured out . He strikes me as more of a king than a creator . And I ' m not sure you can be both . As an experiment , I decided to remake the Book of Genesis as a graphic novel . My version of God is not confident . And maybe not coincidentally , she ' s a woman . It surprised me how few changes I needed to make to the original text , which is sparse and ancient and lends itself well to interpretation . For example , the Bible opens in this mysterious , moody way with God floating aimlessly on the face of a dark , mysterious void . In my version , I have her floating this way because she ' s feeling despondent about her limitations as an artist . She ' s made this messy , wet , mixed up dark first drafts of the world , and she just doesn ' t know where to go from here . My version of God doesn ' t know exactly what she ' s doing , but she draws a horizon line , and things start to fall into place . She banishes Adam and Eve from the Garden of Eden , not because they disobeyed her , but because , by eating the apple and becoming wise , she feels they have outgrown the world she created for them , and she needs to let them go . She scatters the builders of the Tower of Babel , not because she ' s threatened by their power , but because , like any introvert , she needs her privacy . When she destroys the world in the story of Noah  ...

# %% [markdown]
# ## Create the files `file_index.txt` and `tweets.txt`

# %% [markdown]
# ### Create column `text_id`

# %%
df_ted_tc['text_id'] = df_ted_tc['Text ID']

# %% [markdown]
# ### Create column `conversation`

# %%
df_ted_tc['conversation'] = (
        'v:' +
        df_ted_tc['File'].fillna('').astype(str)
)

# %% [markdown]
# #### Replace space by the `_` character

# %% [markdown]
# **Important**: Since the strings in the original columns contain spaces, Pandas creates `file_index.txt` with the columns enclosed with `"` - this caracter causes issues in `examples.sh` when it is executed. Therefore, spaces should be replaced by another character such as underscore.

# %%
# Defining a function to replace space by the '_' character
def replace_space_with_underscore(input_string):
    modified_string = re.sub(r' ', '_', input_string)
    return modified_string

# %%
# Replacing space by the '_' character
df_ted_tc['conversation'] = df_ted_tc['conversation'].apply(replace_space_with_underscore)

# %% [markdown]
# ### Create column `date`

# %%
df_ted_tc['date'] = 'd:' + df_ted_tc['Year'].fillna('').astype(str)

# %% [markdown]
# ### Create column `text_url`

# %% [markdown]
# No URL was considered for all texts.

# %%
df_ted_tc['text_url'] = 'url:' + 'No_URL'

# %% [markdown]
# ### Create column `user`

# %%
df_ted_tc['user'] = (
        'u:' +
        'TED'
)

# %% [markdown]
# ### Create column `content`

# %%
df_ted_tc['content'] = 'c:' + df_ted_tc['Text'].astype(str)

# %% [markdown]
# ### Reorder the created columns

# %% [markdown]
# Please refer to:
# - [Python - List Comprehension 1](https://www.w3schools.com/python/python_lists_comprehension.asp)
# - [Python - List Comprehension 2](https://treyhunner.com/2015/12/python-list-comprehensions-now-in-color/)

# %%
reordered_columns = [
    'text_id',
    'conversation',
    'date',
    'text_url',
    'user',
    'content'
]

# %%
df_ted_tc = df_ted_tc[reordered_columns + [col for col in df_ted_tc.columns if col not in reordered_columns]]

# %%
df_ted_tc
# Out:
#       text_id                  conversation    date    text_url   user  \
# 0     t000000       v:T0004_AM_TED_2019.txt  d:2019  url:No_URL  u:TED
# 1     t000001       v:T0006_AV_TED_2019.txt  d:2019  url:No_URL  u:TED
# 2     t000002      v:T0007_AAB_TED_2019.txt  d:2019  url:No_URL  u:TED
# 3     t000003       v:T0008_BV_TED_2019.txt  d:2019  url:No_URL  u:TED
# 4     t000004   v:T0009_BW_TED_RES_2019.txt  d:2019  url:No_URL  u:TED
# ...       ...                           ...     ...         ...    ...
# 4310  t004312  v:T5897_CH_TED_TWWW_2020.txt  d:2020  url:No_URL  u:TED
# 4311  t004313  v:T5898_EO_TED_TWWW_2020.txt  d:2020  url:No_URL  u:TED
# 4312  t004314  v:T5899_TD_TED_TWWW_2020.txt  d:2020  url:No_URL  u:TED
# 4313  t004315  v:T5900_LR_TED_TWWW_2020.txt  d:2020  url:No_URL  u:TED
# 4314  t004316  v:T5901_LF_TED_TWWW_2020.txt  d:2020  url:No_URL  u:TED
#
#                                                 content  \
# 0     c:I spent the past three years talking to some...
# 1     c:[This is an improvised talk based on a sugge...
# 2     c:So one of the most important solutions to th...
# 3     c:So in the winter of 2012 , I went to visit m...
# 4     c:For all that ' s ever been said about climat...
# ...                                                 ...
# 4310  c:I was not one of those kids that knew exactl...
# 4311  c:When I was pregnant , I just got very frustr...
# 4312  c:When you think about money and your dreams a...
# 4313  c:If you look at a carpenter , they have a too...
# 4314  c:No matter how hard you might try , you can '...
#
#                   Root Directory                        File  \
# 0     CoTED2_TED_TEDEX_1984_2025       T0004_AM_TED_2019.txt
# 1     CoTED2_TED_TEDEX_1984_2025       T0006_AV_TED_2019.txt
# 2     CoTED2_TED_TEDEX_1984_2025      T0007_AAB_TED_2019.txt
# 3     CoTED2_TED_TEDEX_1984_2025       T0008_BV_TED_2019.txt
# 4     CoTED2_TED_TEDEX_1984_2025   T0009_BW_TED_RES_2019.txt
# ...                          ...                         ...
# 4310  CoTED2_TED_TEDEX_1984_2025  T5897_CH_TED_TWWW_2020.txt
# 4311  CoTED2_TED_TEDEX_1984_2025  T5898_EO_TED_TWWW_2020.txt
# 4312  CoTED2_TED_TEDEX_1984_2025  T5899_TD_TED_TWWW_2020.txt
# 4313  CoTED2_TED_TEDEX_1984_2025  T5900_LR_TED_TWWW_2020.txt
# 4314  CoTED2_TED_TEDEX_1984_2025  T5901_LF_TED_TWWW_2020.txt
#
#                                               File Path  Text ID  Year  \
# 0      CoTED2_TED_TEDEX_1984_2025/T0004_AM_TED_2019.txt  t000000  2019
# 1      CoTED2_TED_TEDEX_1984_2025/T0006_AV_TED_2019.txt  t000001  2019
# 2     CoTED2_TED_TEDEX_1984_2025/T0007_AAB_TED_2019.txt  t000002  2019
# 3      CoTED2_TED_TEDEX_1984_2025/T0008_BV_TED_2019.txt  t000003  2019
# 4     CoTED2_TED_TEDEX_1984_2025/T0009_BW_TED_RES_20...  t000004  2019
# ...                                                 ...      ...   ...
# 4310  CoTED2_TED_TEDEX_1984_2025/T5897_CH_TED_TWWW_2...  t004312  2020
# 4311  CoTED2_TED_TEDEX_1984_2025/T5898_EO_TED_TWWW_2...  t004313  2020
# 4312  CoTED2_TED_TEDEX_1984_2025/T5899_TD_TED_TWWW_2...  t004314  2020
# 4313  CoTED2_TED_TEDEX_1984_2025/T5900_LR_TED_TWWW_2...  t004315  2020
# 4314  CoTED2_TED_TEDEX_1984_2025/T5901_LF_TED_TWWW_2...  t004316  2020
#
#       Word Count NLTK                                               Text
# 0                2507  I spent the past three years talking to some o...
# 1                1115  [This is an improvised talk based on a suggest...
# 2                1734  So one of the most important solutions to the ...
# 3                1736  So in the winter of 2012 , I went to visit my ...
# 4                1223  For all that ' s ever been said about climate ...
# ...               ...                                                ...
# 4310              963  I was not one of those kids that knew exactly ...
# 4311             1071  When I was pregnant , I just got very frustrat...
# 4312              752  When you think about money and your dreams and...
# 4313              920  If you look at a carpenter , they have a toolb...
# 4314              813  No matter how hard you might try , you can ' t...
#
# [4315 rows x 13 columns]

# %% [markdown]
# ### Create the file `file_index.txt`

# %%
df_ted_tc[['text_id', 'conversation', 'date', 'text_url']].to_csv('file_index.txt', sep=' ', index=False, header=False, encoding='utf-8', lineterminator='\n')

# %% [markdown]
# ### Create the file `tweets.txt`

# %%
folder = 'tweets'
try:
    os.mkdir(folder)
    print(f"Folder {folder} created!")
except FileExistsError:
    print(f"Folder {folder} already exists")
# Out:
# Folder tweets created!

# %% [markdown]
# Note: The parameters `doublequote=False` and `escapechar=' '` are required to avoid that the column content is doublequoted with '"' in sentences that use characters that need to be escaped such as double quote '"' itself - this causes a malformed response from TreeTagger.

# %%
df_ted_tc[['text_id', 'conversation', 'date', 'user', 'content']].to_csv(f'{folder}/tweets.txt', sep='|', index=False, header=False, encoding='utf-8', lineterminator='\n', doublequote=False, escapechar=' ')

# %% [markdown]
# ## Tag with TreeTagger

# %% [markdown]
# Purpose: Annotate the texts in `tweets/tweets.txt` with part-of-speech and lemma information.
# - Input
#     - `file_index.txt`
#     - `tweets/tweets.txt`
# - Output
#     - `tweets/tagged.txt`

# %% [markdown]
# ## Process `tokenstypes`

# %% [markdown]
# Purpose: Capture the content tokens (specific occurrences of words) and the content types (general concept of words) from `tweets/tagged.txt`.
# - Input
#     - `file_index.txt`
#     - `tweets/tagged.txt`
# - Output
#     - `tweets/tokens.txt`
#     - `tweets/types.txt`

# %% [markdown]
# ## Process `toplemmas`

# %% [markdown]
# `toplemmas` was processed for comparison with the keywords extraction.

# %% [markdown]
# Purpose: Determine the 1.000 top lemmas. **Important**: This process requires manual inspection. Non-meaningful lemmas should be excluded by updating `stoplist.sed` and reiterating the processing.
# - Input
#     - `tweets/types.txt`
#     - `stoplist.sed`: List of rules that allows the exclusion of a certain lemmas
# - Output
#     - `selectedwords` = `var_index.txt`

# %% [markdown]
# ## Process `keywords_text_counts.py`, `select_kws.py`, and `select_kws_make_selectedwords.py`

# %% [markdown]
# ### Enrich the Target Corpus with the tokens from `tokenstypes`

# %%
df_ted_tc = pd.read_json(f"{output_directory}/{dataset_filename_3}.jsonl", lines=True)

# %%
df_ted_tc['text_id'] = df_ted_tc['Text ID']

# %%
df_ted_tc_columns = df_ted_tc.columns.tolist()
print(df_ted_tc_columns)
# Out:
# ['Root Directory', 'File', 'File Path', 'Text ID', 'Year', 'Word Count NLTK', 'Text', 'text_id']

# %%
reordered_columns = [
    'Root Directory',
    'File',
    'File Path',
    'text_id'
]

# %%
df_ted_tc = df_ted_tc[reordered_columns + [col for col in df_ted_tc.columns if col not in reordered_columns]]

# %%
folder = 'tweets'
column_names = ['text_id', 'Text Tokens']

# Safe read: parse each line, splitting once on the literal "|c:"
records = []
with open(f"{folder}/tokens.txt", 'r', encoding='utf-8', errors='replace') as f:
    for lineno, line in enumerate(f, start=1):
        line = line.rstrip('\n')
        if not line:
            continue
        # Split once on the exact marker
        if '|c:' not in line:
            # Optionally log/skip malformed lines
            # print(f"Skipping malformed line {lineno}: {line}")
            continue
        left, right = line.split('|c:', 1)
        records.append((left, right.strip()))

df_tokens = pd.DataFrame(records, columns=column_names)

# %%
df_ted_tc_2 = df_ted_tc.merge(df_tokens, on='text_id', how='left')

# %%
df_ted_tc_2
# Out:
#                   Root Directory                        File  \
# 0     CoTED2_TED_TEDEX_1984_2025       T0004_AM_TED_2019.txt
# 1     CoTED2_TED_TEDEX_1984_2025       T0006_AV_TED_2019.txt
# 2     CoTED2_TED_TEDEX_1984_2025      T0007_AAB_TED_2019.txt
# 3     CoTED2_TED_TEDEX_1984_2025       T0008_BV_TED_2019.txt
# 4     CoTED2_TED_TEDEX_1984_2025   T0009_BW_TED_RES_2019.txt
# ...                          ...                         ...
# 4310  CoTED2_TED_TEDEX_1984_2025  T5897_CH_TED_TWWW_2020.txt
# 4311  CoTED2_TED_TEDEX_1984_2025  T5898_EO_TED_TWWW_2020.txt
# 4312  CoTED2_TED_TEDEX_1984_2025  T5899_TD_TED_TWWW_2020.txt
# 4313  CoTED2_TED_TEDEX_1984_2025  T5900_LR_TED_TWWW_2020.txt
# 4314  CoTED2_TED_TEDEX_1984_2025  T5901_LF_TED_TWWW_2020.txt
#
#                                               File Path  text_id  Text ID  \
# 0      CoTED2_TED_TEDEX_1984_2025/T0004_AM_TED_2019.txt  t000000  t000000
# 1      CoTED2_TED_TEDEX_1984_2025/T0006_AV_TED_2019.txt  t000001  t000001
# 2     CoTED2_TED_TEDEX_1984_2025/T0007_AAB_TED_2019.txt  t000002  t000002
# 3      CoTED2_TED_TEDEX_1984_2025/T0008_BV_TED_2019.txt  t000003  t000003
# 4     CoTED2_TED_TEDEX_1984_2025/T0009_BW_TED_RES_20...  t000004  t000004
# ...                                                 ...      ...      ...
# 4310  CoTED2_TED_TEDEX_1984_2025/T5897_CH_TED_TWWW_2...  t004312  t004312
# 4311  CoTED2_TED_TEDEX_1984_2025/T5898_EO_TED_TWWW_2...  t004313  t004313
# 4312  CoTED2_TED_TEDEX_1984_2025/T5899_TD_TED_TWWW_2...  t004314  t004314
# 4313  CoTED2_TED_TEDEX_1984_2025/T5900_LR_TED_TWWW_2...  t004315  t004315
# 4314  CoTED2_TED_TEDEX_1984_2025/T5901_LF_TED_TWWW_2...  t004316  t004316
#
#       Year  Word Count NLTK  \
# 0     2019             2507
# 1     2019             1115
# 2     2019             1734
# 3     2019             1736
# 4     2019             1223
# ...    ...              ...
# 4310  2020              963
# 4311  2020             1071
# 4312  2020              752
# 4313  2020              920
# 4314  2020              813
#
#                                                    Text  \
# 0     I spent the past three years talking to some o...
# 1     [This is an improvised talk (and intro) based ...
# 2     So one of the most important solutions to the ...
# 3     So in the winter of 2012, I went to visit my g...
# 4     For all that's ever been said about climate ch...
# ...                                                 ...
# 4310  I was not one of those kids that knew exactly ...
# 4311  When I was pregnant, I just got very frustrate...
# 4312  When you think about money and your dreams and...
# 4313  If you look at a carpenter, they have a toolbo...
# 4314  No matter how hard you might try, you can't ju...
#
#                                             Text Tokens
# 0     spend past year talk bad people internet onlin...
# 1     improvise talk base suggest topic audience spe...
# 2     important solution global challenge pose clima...
# 3     winter go visit grandmother house place way mo...
# 4     say climate change haven hear psychological im...
# ...                                                 ...
# 4310  kid know want do grow last year career english...
# 4311  pregnant get frustrated eat deli meat do parti...
# 4312  think money dream re look account re bank acco...
# 4313  look carpenter toolbox dentist drill era type ...
# 4314  matter hard try flip switch step office turn e...
#
# [4315 rows x 9 columns]

# %% [markdown]
# ### Export to a file

# %%
df_ted_tc_2.to_json(f"{output_directory}/{dataset_filename_4}.jsonl", orient='records', lines=True)

# %%
df_ted_tc_2.to_excel(f"{output_directory}/{dataset_filename_4}.xlsx", index=False)

# %% [markdown]
# ### Create `lemma_tokens` directory structure and write token files per `text_id` grouped by `Year`

# %%
base_dir = os.path.join('tweets', 'lemma_tokens')
os.makedirs(base_dir, exist_ok=True)

required_cols = {'text_id', 'Year', 'Text Tokens'}
missing = required_cols - set(df_ted_tc_2.columns)
if missing:
    raise KeyError(f"Missing required columns in df_ted_tc_2: {missing}")

for _, row in df_ted_tc_2.iterrows():
    doc_type = str(row['Year']) if pd.notna(row['Year']) else 'Unknown'
    text_id = str(row['text_id'])
    tokens_str = row['Text Tokens']

    # Ensure directory for this Year exists
    target_dir = os.path.join(base_dir, doc_type)
    os.makedirs(target_dir, exist_ok=True)

    # Prepare tokens list: assume space-separated tokens in 'Text Tokens'
    if pd.isna(tokens_str):
        tokens = []
    else:
        tokens = str(tokens_str).split()

    out_path = os.path.join(target_dir, f"{text_id}.txt")
    with open(out_path, 'w', encoding='utf-8', newline='\n') as fh:
        fh.write('\n'.join(tokens))

# %% [markdown]
# ## Process `sas`

# %% [markdown]
# Purpose: Prepare input data for processing in SAS.
# - Input
#     - `tweets/types.txt`
#     - `selectedwords`
#     - `file_index.txt`
# - Output
#     - `columns`
#     - `sas/data.txt`
#     - `sas/dates.txt`
#     - `sas/wcount.txt`

# %% [markdown]
# ## Process `datamatrix`

# %% [markdown]
# Purpose: Prepares input data for calculating the correlation matrix.
# - Input
#     - `file_index.txt`
#     - `columns`
#     - `selectedwords`
# - Output
#     - `file_ids.txt`
#     - `data.csv`

# %% [markdown]
# ## Process `correlationmatrix`

# %% [markdown]
# Purpose: Calculates the correlation matrix.
# - Input
#     - `data.csv`
# - Output
#     - `correlation`

# %% [markdown]
# ## Process `formats`

# %% [markdown]
# Purpose: Prepare input data for processing in SAS.
# - Input
#     - `data.csv`
#     - `selectedwords`
# - Output
#     - `sas/corr.txt`
#     - `sas/word_labels_format.sas`

# %% [markdown]
# ## Process the statistical procedures on SAS

# %% [markdown]
# - Log in to your [SAS OnDemand for Academics](https://welcome.oda.sas.com/) account
# - Proceed as indicated in this [video tutorial](https://youtu.be/I3u9zD3jyOA?si=68uIKVc2iusGG2KY)

# %% [markdown]
# ## Process `examples`

# %% [markdown]
# Purpose: Extract examples for analysis.
# - Input
#     - `sas/output_"$project"/loadtable.html`
#     - `sas/output_"$project"/"$project"_scores.tsv`
#     - `sas/output_"$project"/"$project"_scores_only.tsv`
# - Output
#     - `examples/factors`
#     - `example files`

# %% [markdown]
# ## Corpus Design information

# %% [markdown]
# ### Define input variables

# %%
input_directory = 'sas'
output_directory = 'sas'

# %% [markdown]
# ### Import `sas/wcount.txt` into a DataFrame

# %%
# Define the column names
column_names = ['Text ID', 'Word Count']

# Import the file
df_wcount = pd.read_csv(f"{input_directory}/wcount.txt", sep=' ', header=None, names=column_names)

# %%
df_wcount
# Out:
#       Text ID  Word Count
# 0     t000000        2564
# 1     t000001        1092
# 2     t000002        1778
# 3     t000003        1782
# 4     t000004        1264
# ...       ...         ...
# 4310  t004312        1001
# 4311  t004313        1126
# 4312  t004314         784
# 4313  t004315         951
# 4314  t004316         849
#
# [4315 rows x 2 columns]

# %%
# Select the series
series = df_wcount['Word Count'].dropna()

# Summary stats
mean_val = series.mean()
std_val = series.std(ddof=1)  # sample standard deviation
desc = series.describe()  # count, mean, std, min, 25%, 50%, 75%, max

print('Descriptive statistics for Word Count:')
print(f"- Count: {int(desc['count'])}")
print(f"- Mean: {mean_val:.2f}")
print(f"- Std (sample): {std_val:.2f}")
print(f"- Min: {int(desc['min'])}")
print(f"- Q1 (25%): {desc['25%']:.2f}")
print(f"- Median (50%): {desc['50%']:.2f}")
print(f"- Q3 (75%): {desc['75%']:.2f}")
print(f"- Max: {int(desc['max'])}")

# IQR-based outlier detection
q1, q3 = series.quantile([0.25, 0.75])
iqr = q3 - q1
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr

outlier_mask = (series < lower_fence) | (series > upper_fence)
outliers = (
    df_wcount.loc[outlier_mask, ['Text ID', 'Word Count']]
    .sort_values('Word Count')
    .reset_index(drop=True)
)

print(f"\nIQR outlier thresholds:")
print(f"- Lower fence: {lower_fence:.2f}")
print(f"- Upper fence: {upper_fence:.2f}")
print(f"Outliers found: {len(outliers)}")
display(outliers)

# Box plot
plt.figure(figsize=(9, 1.8))
sns.boxplot(x=series, color='steelblue')
plt.title('Box plot of Word Count (df_wcount)')
plt.xlabel('Tokens')
plt.tight_layout()

# Saving the plot
plt.savefig(f"{output_directory}/{dataset_filename_4}_boxplot.png", dpi=300)

plt.show()

# Raw scale: Histogram + KDE
plt.figure(figsize=(9, 4))
sns.histplot(series, bins='auto', kde=True, color='steelblue')
plt.title('Histogram + KDE of Word Count (raw scale)')
plt.xlabel('Tokens')
plt.ylabel('Frequency')
plt.tight_layout()

# Saving the plot
plt.savefig(f"{output_directory}/{dataset_filename_4}_histogram.png", dpi=300)

plt.show()

# Log scale via transformation: Histogram + KDE
log_series = np.log1p(series)  # log(1 + x) to handle zeros safely
plt.figure(figsize=(9, 4))
sns.histplot(log_series, bins='auto', kde=True, color='indianred')
plt.title('Histogram + KDE of log1p(Word Count)')
plt.xlabel('log1p(Tokens)')
plt.ylabel('Frequency')
plt.tight_layout()

# Saving the plot
plt.savefig(f"{output_directory}/{dataset_filename_4}_histogram_log_scale.png", dpi=300)

plt.show()
# Out:
# Descriptive statistics for Word Count:
# - Count: 4315
# - Mean: 2023.73
# - Std (sample): 1133.08
# - Min: 369
# - Q1 (25%): 1327.50
# - Median (50%): 1859.00
# - Q3 (75%): 2525.00
# - Max: 13569
#
# IQR outlier thresholds:
# - Lower fence: -468.75
# - Upper fence: 4321.25
# Outliers found: 101
#      Text ID  Word Count
# 0    t003536        4410
# 1    t000434        4413
# 2    t000481        4420
# 3    t000222        4444
# 4    t000208        4463
# ..       ...         ...
# 96   t004288       11166
# 97   t004291       11482
# 98   t004300       12422
# 99   t004019       12443
# 100  t004290       13569
#
# [101 rows x 2 columns]

# %% [markdown]
# ### Import `sas/dates.txt` into a DataFrame

# %%
# Define the column names
column_names = ['Text ID', 'Year']

# Import the file
df_dates = pd.read_csv(f"{input_directory}/dates.txt", sep=' ', header=None, names=column_names)

# %%
df_dates
# Out:
#       Text ID  Year
# 0     t000000  2019
# 1     t000001  2019
# 2     t000002  2019
# 3     t000003  2019
# 4     t000004  2019
# ...       ...   ...
# 4310  t004312  2020
# 4311  t004313  2020
# 4312  t004314  2020
# 4313  t004315  2020
# 4314  t004316  2020
#
# [4315 rows x 2 columns]

# %% [markdown]
# ### Combining the `df_dates` and `df_wcount` DataFrames into `df_corpus_design` DataFrame

# %%
# Merge the DataFrames on 'Text ID'
merged_df = pd.merge(df_dates, df_wcount, on='Text ID')

# Group by ('Year 1', 'Year 2') to get 'Text Count' and 'Word Count'
df_corpus_design = merged_df.groupby(['Year']).agg({
    'Text ID': 'count',
    'Word Count': 'sum'
}).reset_index()

# Rename columns to match the requirements
df_corpus_design.rename(columns={'Text ID': 'Text Count'}, inplace=True)

# Append totals row at the bottom
totals_row = {
    'Year': 'Total',
    'Text Count': df_corpus_design['Text Count'].sum(),
    'Word Count': df_corpus_design['Word Count'].sum()
}
df_corpus_design = pd.concat([df_corpus_design, pd.DataFrame([totals_row])], ignore_index=True)

df_corpus_design
# Out:
#      Year  Text Count  Word Count
# 0    1984           1        3940
# 1    1990           1        5866
# 2    1994           1        3265
# 3    1998           6       17459
# 4    2001           4       11239
# 5    2002          25       72682
# 6    2003          31       91954
# 7    2004          30       84353
# 8    2005          61      189230
# 9    2006          41      109841
# 10   2007         101      257921
# 11   2008          74      196904
# 12   2009         200      420985
# 13   2010         219      482509
# 14   2011         235      492069
# 15   2012         253      513077
# 16   2013         266      523127
# 17   2014         237      461183
# 18   2015         237      468258
# 19   2016         271      521828
# 20   2017         342      632998
# 21   2018         261      436292
# 22   2019         104      185560
# 23   2020         281      611369
# 24   2021         294      500674
# 25   2022         246      483646
# 26   2023         284      504436
# 27   2024         205      435907
# 28   2025           4       13821
# 29  Total        4315     8732393

# %% [markdown]
# ### Create a LaTeX table

# %%
title = 'Text and Word Count by Year Range'
filename = 'df_corpus_design'

# %%
caption = title
label = f"tab:{filename}"
tex_filename = f"{filename}.tex"

# %%
tex_table = df_corpus_design.to_latex(longtable=True, caption=caption, label=label)

# %%
with open(f"{output_directory}/{tex_filename}", 'w', encoding='utf8', newline='\n') as file:
    file.write(tex_table)
